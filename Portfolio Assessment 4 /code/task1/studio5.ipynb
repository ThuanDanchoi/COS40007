# %%
# !pip install labelme
# Out:
# Requirement already satisfied: labelme in /opt/anaconda3/lib/python3.12/site-packages (5.8.1)
# Requirement already satisfied: imgviz in /opt/anaconda3/lib/python3.12/site-packages (from labelme) (1.7.6)
# Requirement already satisfied: loguru in /opt/anaconda3/lib/python3.12/site-packages (from labelme) (0.7.3)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.12/site-packages (from labelme) (3.8.4)
# Requirement already satisfied: natsort>=7.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from labelme) (8.4.0)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (from labelme) (1.26.4)
# Requirement already satisfied: osam>=0.2.3 in /opt/anaconda3/lib/python3.12/site-packages (from labelme) (0.2.3)
# Requirement already satisfied: pillow>=2.8 in /opt/anaconda3/lib/python3.12/site-packages (from labelme) (10.2.0)
# Requirement already satisfied: pyqt5>=5.14.0 in /opt/anaconda3/lib/python3.12/site-packages (from labelme) (5.15.10)
# Requirement already satisfied: pyyaml in /opt/anaconda3/lib/python3.12/site-packages (from labelme) (6.0.2)
# Requirement already satisfied: scikit-image in /opt/anaconda3/lib/python3.12/site-packages (from labelme) (0.23.2)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.12/site-packages (from osam>=0.2.3->labelme) (8.1.3)
# Requirement already satisfied: gdown in /opt/anaconda3/lib/python3.12/site-packages (from osam>=0.2.3->labelme) (5.2.0)
# Requirement already satisfied: onnxruntime!=1.16.0,!=1.20.0,!=1.20.1,>=1.14.1 in /opt/anaconda3/lib/python3.12/site-packages (from osam>=0.2.3->labelme) (1.21.0)
# Requirement already satisfied: pydantic in /opt/anaconda3/lib/python3.12/site-packages (from osam>=0.2.3->labelme) (2.5.3)
# Requirement already satisfied: PyQt5-sip<13,>=12.13 in /opt/anaconda3/lib/python3.12/site-packages (from pyqt5>=5.14.0->labelme) (12.13.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->labelme) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->labelme) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->labelme) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->labelme) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->labelme) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->labelme) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib->labelme) (2.8.2)
# Requirement already satisfied: scipy>=1.9 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-image->labelme) (1.13.1)
# Requirement already satisfied: networkx>=2.8 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-image->labelme) (3.2.1)
# Requirement already satisfied: imageio>=2.33 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-image->labelme) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-image->labelme) (2023.4.12)
# Requirement already satisfied: lazy-loader>=0.4 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-image->labelme) (0.4)
# Requirement already satisfied: coloredlogs in /opt/anaconda3/lib/python3.12/site-packages (from onnxruntime!=1.16.0,!=1.20.0,!=1.20.1,>=1.14.1->osam>=0.2.3->labelme) (15.0.1)
# Requirement already satisfied: flatbuffers in /opt/anaconda3/lib/python3.12/site-packages (from onnxruntime!=1.16.0,!=1.20.0,!=1.20.1,>=1.14.1->osam>=0.2.3->labelme) (24.3.25)
# Requirement already satisfied: protobuf in /opt/anaconda3/lib/python3.12/site-packages (from onnxruntime!=1.16.0,!=1.20.0,!=1.20.1,>=1.14.1->osam>=0.2.3->labelme) (3.20.3)
# Requirement already satisfied: sympy in /opt/anaconda3/lib/python3.12/site-packages (from onnxruntime!=1.16.0,!=1.20.0,!=1.20.1,>=1.14.1->osam>=0.2.3->labelme) (1.13.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->labelme) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/lib/python3.12/site-packages (from gdown->osam>=0.2.3->labelme) (4.12.3)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.12/site-packages (from gdown->osam>=0.2.3->labelme) (3.13.1)
# Requirement already satisfied: requests[socks] in /opt/anaconda3/lib/python3.12/site-packages (from gdown->osam>=0.2.3->labelme) (2.32.3)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.12/site-packages (from gdown->osam>=0.2.3->labelme) (4.66.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic->osam>=0.2.3->labelme) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic->osam>=0.2.3->labelme) (2.14.6)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic->osam>=0.2.3->labelme) (4.11.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.12/site-packages (from beautifulsoup4->gdown->osam>=0.2.3->labelme) (2.5)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/anaconda3/lib/python3.12/site-packages (from coloredlogs->onnxruntime!=1.16.0,!=1.20.0,!=1.20.1,>=1.14.1->osam>=0.2.3->labelme) (10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests[socks]->gdown->osam>=0.2.3->labelme) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests[socks]->gdown->osam>=0.2.3->labelme) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests[socks]->gdown->osam>=0.2.3->labelme) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests[socks]->gdown->osam>=0.2.3->labelme) (2024.7.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/anaconda3/lib/python3.12/site-packages (from requests[socks]->gdown->osam>=0.2.3->labelme) (1.7.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from sympy->onnxruntime!=1.16.0,!=1.20.0,!=1.20.1,>=1.14.1->osam>=0.2.3->labelme) (1.3.0)

# %%
import os
import sys
import cv2
from PIL import Image

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input

# %% [markdown]
# # Activity 1: Class Labelling

# %% [markdown]
# # Activity 2: Custom CNN

# %%
# Load the data
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Preprocess the data
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
x_train = np.expand_dims(x_train, - 1)
x_test = np.expand_dims(x_test, -1)

# Convert class vectors to binary class 
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

# Build the model
model = keras.Sequential([
    keras.Input(shape=(28, 28, 1)),
    layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Flatten(),
    layers.Dropout(0.5),
    layers.Dense(10, activation='softmax')
])

# Compile the model
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# Train the model
batch_size = 128
epochs = 5

history = model.fit(
    x_train, y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.1
)

# Evaluate the model
score = model.evaluate(x_test, y_test, verbose=0)
print(f"Test loss: {score[0]}")
print(f"Test accuracy: {score[1]}")

# %% [markdown]
# # Activity 3: Transfer Learning with ResNet

# %% [markdown]
# # Activity 4: Recursive CNN for object detection
