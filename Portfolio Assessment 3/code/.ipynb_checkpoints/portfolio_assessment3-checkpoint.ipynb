# %% [markdown]
# # Portfolio Assessment3
# ## Duc Thuan Tran 104330455

# %%
import os
import sys

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import SelectKBest, f_classif, RFE
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier, export_text
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.utils import resample
from imblearn.over_sampling import SMOTE
import pickle

# %%
df = pd.read_csv('vegemite.csv')

# %% [markdown]
# # Step 1: Data Preparation

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15237 entries, 0 to 15236
# Data columns (total 47 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   FFTE Feed tank level SP        15237 non-null  float64
#  1   FFTE Production solids SP      15237 non-null  float64
#  2   FFTE Steam pressure SP         15237 non-null  float64
#  3   TFE Out flow SP                15237 non-null  float64
#  4   TFE Production solids SP       15237 non-null  float64
#  5   TFE Vacuum pressure SP         15237 non-null  float64
#  6   TFE Steam pressure SP          15237 non-null  float64
#  7   TFE Steam temperature SP       15237 non-null  float64
#  8   FFTE Feed flow SP              15237 non-null  float64
#  9   FFTE Out steam temp SP         15237 non-null  float64
#  10  Extract tank Level             15237 non-null  float64
#  11  Extract tank Out flow PV       15237 non-null  float64
#  12  FFTE Discharge density         15237 non-null  float64
#  13  FFTE Discharge solids          15237 non-null  float64
#  14  FFTE Feed flow rate PV         15237 non-null  float64
#  15  FFTE Feed tank level PV        15237 non-null  float64
#  16  FFTE Heat temperature 1        15237 non-null  float64
#  17  FFTE Heat temperature 2        15237 non-null  float64
#  18  FFTE Heat temperature 3        15237 non-null  float64
#  19  FFTE Out steam temp PV         15237 non-null  float64
#  20  FFTE Production solids PV      15237 non-null  float64
#  21  FFTE Pump 1                    15237 non-null  float64
#  22  FFTE Pump 1 - 2                15237 non-null  float64
#  23  FFTE Pump 2                    15237 non-null  float64
#  24  FFTE Steam pressure PV         15237 non-null  float64
#  25  FFTE Temperature 1 - 1         15237 non-null  float64
#  26  FFTE Temperature 1 - 2         15237 non-null  float64
#  27  FFTE Temperature 2 - 1         15237 non-null  float64
#  28  FFTE Temperature 2 - 2         15237 non-null  float64
#  29  FFTE Temperature 3 - 1         15237 non-null  float64
#  30  FFTE Temperature 3 - 2         15237 non-null  float64
#  31  FFTE Unk Temperature           15237 non-null  float64
#  32  TFE Feed pump                  15237 non-null  float64
#  33  TFE Input flow PV              15237 non-null  float64
#  34  TFE Level                      15237 non-null  float64
#  35  TFE Motor current              15237 non-null  float64
#  36  TFE Motor speed                15237 non-null  float64
#  37  TFE Out flow PV                15237 non-null  float64
#  38  TFE Product out temperature    15237 non-null  float64
#  39  TFE Production solids PV       15237 non-null  float64
#  40  TFE Production solids density  15237 non-null  float64
#  41  TFE Steam pressure PV          15237 non-null  float64
#  42  TFE Steam temperature          15237 non-null  float64
#  43  TFE Tank level                 15237 non-null  float64
#  44  TFE Temperature                15237 non-null  float64
#  45  TFE Vacuum pressure PV         15237 non-null  float64
#  46  Class                          15237 non-null  int64
# dtypes: float64(46), int64(1)
# memory usage: 5.5 MB

# %%
df.head()
# Out:
#    FFTE Feed tank level SP  FFTE Production solids SP  FFTE Steam pressure SP  \
# 0                     50.0                      40.74                   125.0
# 1                     50.0                      40.74                   125.0
# 2                     50.0                      40.74                   125.0
# 3                     50.0                      40.74                   125.0
# 4                     50.0                      39.00                    90.0
#
#    TFE Out flow SP  TFE Production solids SP  TFE Vacuum pressure SP  \
# 0          2897.65                      69.0                  -80.00
# 1          2897.65                      69.0                  -79.45
# 2          2897.65                      69.0                  -71.54
# 3          2897.65                      69.0                  -68.44
# 4          2694.62                      64.0                  -80.00
#
#    TFE Steam pressure SP  TFE Steam temperature SP  FFTE Feed flow SP  \
# 0                  125.0                      80.0            10130.0
# 1                  125.0                      80.0            10130.0
# 2                  125.0                      80.0            10130.0
# 3                  125.0                      80.0            10130.0
# 4                  120.0                      80.0             9300.0
#
#    FFTE Out steam temp SP  ...  TFE Out flow PV  TFE Product out temperature  \
# 0                   49.88  ...          2577.82                          0.0
# 1                   49.88  ...          1551.88                          0.0
# 2                   49.88  ...          1564.85                          0.0
# 3                   49.88  ...          1512.97                          0.0
# 4                   49.88  ...          1795.72                          0.0
#
#    TFE Production solids PV  TFE Production solids density  \
# 0                     62.87                           1.19
# 1                     67.98                           1.19
# 2                     70.38                           1.19
# 3                     69.18                           1.19
# 4                     41.14                           0.90
#
#    TFE Steam pressure PV  TFE Steam temperature  TFE Tank level  \
# 0                 125.03                  72.68           83.68
# 1                 125.03                  64.66           82.95
# 2                 124.71                  65.63           82.77
# 3                 124.71                  74.35           82.55
# 4                 119.91                  70.82           83.96
#
#    TFE Temperature  TFE Vacuum pressure PV  Class
# 0             71.0                  -77.74      1
# 1             69.0                  -79.49      1
# 2             72.0                  -75.28      1
# 3             76.0                  -69.65      1
# 4             71.0                  -75.28      1
#
# [5 rows x 47 columns]

# %%
df.shape
# Out:
# (15237, 47)

# %%
df.tail()
# Out:
#        FFTE Feed tank level SP  FFTE Production solids SP  \
# 15232                     50.0                       41.5
# 15233                     50.0                       41.5
# 15234                     50.0                       41.5
# 15235                     50.0                       41.5
# 15236                     50.0                       41.5
#
#        FFTE Steam pressure SP  TFE Out flow SP  TFE Production solids SP  \
# 15232                   135.0           1925.3                      71.0
# 15233                   135.0           1925.3                      71.0
# 15234                   135.0           1925.3                      71.0
# 15235                   135.0           1925.3                      71.0
# 15236                   135.0           1925.3                      71.0
#
#        TFE Vacuum pressure SP  TFE Steam pressure SP  \
# 15232                  -63.12                  120.0
# 15233                  -69.46                  120.0
# 15234                  -68.95                  120.0
# 15235                  -62.23                  120.0
# 15236                  -52.04                  120.0
#
#        TFE Steam temperature SP  FFTE Feed flow SP  FFTE Out steam temp SP  \
# 15232                      80.0             9400.0                    50.4
# 15233                      80.0             9400.0                    50.4
# 15234                      80.0             9400.0                    50.4
# 15235                      80.0             9400.0                    50.4
# 15236                      80.0             9400.0                    50.4
#
#        ...  TFE Out flow PV  TFE Product out temperature  \
# 15232  ...          4532.43                          0.0
# 15233  ...          2680.29                          0.0
# 15234  ...          1859.92                          0.0
# 15235  ...          2590.14                          0.0
# 15236  ...          2590.14                          0.0
#
#        TFE Production solids PV  TFE Production solids density  \
# 15232                     70.84                           1.25
# 15233                     70.09                           1.25
# 15234                     70.09                           1.25
# 15235                     70.09                           1.25
# 15236                     70.09                           1.25
#
#        TFE Steam pressure PV  TFE Steam temperature  TFE Tank level  \
# 15232                 119.91                  73.84           83.28
# 15233                 119.91                  73.46           83.72
# 15234                 119.91                  63.73           84.20
# 15235                 119.91                  71.21           86.23
# 15236                 119.91                  71.21           86.23
#
#        TFE Temperature  TFE Vacuum pressure PV  Class
# 15232             74.0                  -73.50      2
# 15233             73.0                  -75.64      2
# 15234             72.0                  -76.32      2
# 15235             70.0                  -77.39      2
# 15236             70.0                  -77.03      2
#
# [5 rows x 47 columns]

# %%
df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
df['Class'].value_counts()
# Out:
# Class
# 2    7548
# 1    5047
# 0    2642
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data = df, x='Class')
plt.title("Distribution of Class")
plt.xlabel("Class")
plt.ylabel("Count")
plt.show()

# %%
# 1. Shuffle the dataset
df = df.sample(frac=1, random_state=42).reset_index(drop=True)

# 2. Randomly take out 1000 data points with balanced classes
test_samples = []
class_distribution = {0:334, 1:333, 2:333}

for class_value, sample_count in class_distribution.items():
    class_rows = df[df['Class'] == class_value]

    if len(class_rows) < sample_count:
        print(f"Warning: Not enough samples for class {class_value}. Only {len(class_rows)} available.")
        sample_count = len(class_rows)

    selected = class_rows.sample(n=sample_count, random_state=42)
    test_samples.append(selected)
    print(f"Selected {sample_count} samples from class {class_value}")

    df = df[~df.index.isin(selected.index)]

test_df = pd.concat(test_samples).reset_index(drop=True)

train_df = df.reset_index(drop=True)
# Out:
# Selected 334 samples from class 0
# Selected 333 samples from class 1
# Selected 333 samples from class 2

# %%
test_df.shape
# Out:
# (1000, 47)

# %%
train_df.shape
# Out:
# (14237, 47)

# %% [markdown]
# ## Features Constructing

# %% [markdown]
# ### 1. Checking for constant value columns

# %%
constant_cols = [col for col in train_df.columns if train_df[col].nunique() == 1]

if constant_cols:
    # Remove constant columns
    train_df = train_df.drop(columns=constant_cols)
    test_df = test_df.drop(columns=constant_cols)

constant_cols
# Out:
# ['TFE Steam temperature SP', 'TFE Product out temperature']

# %% [markdown]
# ### 2. Checking for column with few integer values

# %%
few_integer_cols = []
for col in train_df.columns:
    if train_df[col].dtype in ['int64', 'float64']:
        unique_values = train_df[col].nunique()
        if unique_values < 10 and col != 'Class':
            few_integer_cols.append(col)

# Convert integer columns to category
for col in few_integer_cols:
    train_df[col] = train_df[col].astype('category')
    test_df[col] = test_df[col].astype('category')
    print(f"Converted {col} to categorical")
# Out:
# Converted FFTE Feed tank level SP to categorical
# Converted FFTE Pump 1 to categorical
# Converted FFTE Pump 1 - 2 to categorical
# Converted FFTE Pump 2 to categorical
# Converted TFE Motor speed to categorical

# %% [markdown]
# ### 3. Checking for class balanced distribution

# %%
# 3. Checking for class balanced distribution
class_counts = train_df['Class'].value_counts()

class_counts
# Out:
# Class
# 2    7215
# 1    4714
# 0    2308
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data = train_df, x='Class')
plt.title("Distribution of Class in Training Data")
plt.xlabel("Class")
plt.ylabel("Count")
plt.show()

# %%
# Choosing the methods base on the ratio performance
min_class_count = class_counts.min()
max_class_count = class_counts.max()
imbalance_ratio = min_class_count / max_class_count

print(f"Imbalance ratio (min/max): {imbalance_ratio:.4f}")

BALANCED_THRESHOLD = 0.8
MODERATE_IMBALANCE = 0.5
SEVERE_IMBALANCE = 0.2

if imbalance_ratio >= BALANCED_THRESHOLD:
    print("Classes are fairly balanced. No resampling needed.")
    resampling_method = None
elif imbalance_ratio >= MODERATE_IMBALANCE:
    print("Moderate class imbalance detected. Will use class weights in model training.")
    class_weights = {i: len(train_df) / (len(np.unique(train_df['Class'])) * count) 
                      for i, count in enumerate(class_counts)}
    print(f"Class weights: {class_weights}")
    resampling_method = "class_weights"
elif imbalance_ratio >= SEVERE_IMBALANCE:
    print("Significant class imbalance detected. Will apply SMOTE oversampling.")
    resampling_method = "smote"
else:
    print("Severe class imbalance detected. Will apply combination of undersampling and SMOTE.")
    resampling_method = "undersampling+smote"
# Out:
# Imbalance ratio (min/max): 0.3199
# Significant class imbalance detected. Will apply SMOTE oversampling.

# %% [markdown]
# #### SMOTE

# %%
X = train_df.drop('Class', axis=1)
y = train_df['Class']

print("Class distribution before resampling:")
print(y.value_counts())

# Apply SMOTE
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Create a new DataFrame with the resampled data
resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
resampled_df['Class'] = y_resampled

print("Class distribution after resampling:")
print(pd.Series(y_resampled).value_counts())

train_df = resampled_df
# Out:
# Class distribution before resampling:
# Class
# 2    7215
# 1    4714
# 0    2308
# Name: count, dtype: int64
# Class distribution after resampling:
# Class
# 2    7215
# 0    7215
# 1    7215
# Name: count, dtype: int64

# %% [markdown]
# ### 4. Checking for composite features through exploration

# %%
train_df.corr()
# Out:
#                                FFTE Feed tank level SP  \
# FFTE Feed tank level SP                       1.000000
# FFTE Production solids SP                    -0.091925
# FFTE Steam pressure SP                       -0.244767
# TFE Out flow SP                              -0.047703
# TFE Production solids SP                      0.312707
# TFE Vacuum pressure SP                       -0.272909
# TFE Steam pressure SP                         0.564166
# FFTE Feed flow SP                            -0.523272
# FFTE Out steam temp SP                        0.032591
# Extract tank Level                            0.072949
# Extract tank Out flow PV                     -0.127893
# FFTE Discharge density                       -0.029771
# FFTE Discharge solids                         0.292682
# FFTE Feed flow rate PV                       -0.267865
# FFTE Feed tank level PV                       0.218314
# FFTE Heat temperature 1                       0.108154
# FFTE Heat temperature 2                       0.204008
# FFTE Heat temperature 3                       0.228728
# FFTE Out steam temp PV                        0.037676
# FFTE Production solids PV                     0.293127
# FFTE Pump 1                                   0.128699
# FFTE Pump 1 - 2                               0.016694
# FFTE Pump 2                                   0.196759
# FFTE Steam pressure PV                       -0.104140
# FFTE Temperature 1 - 1                        0.202938
# FFTE Temperature 1 - 2                        0.172163
# FFTE Temperature 2 - 1                        0.195128
# FFTE Temperature 2 - 2                        0.135604
# FFTE Temperature 3 - 1                       -0.014358
# FFTE Temperature 3 - 2                        0.203238
# FFTE Unk Temperature                          0.055515
# TFE Feed pump                                -0.028782
# TFE Input flow PV                            -0.168371
# TFE Level                                    -0.077774
# TFE Motor current                             0.107589
# TFE Motor speed                               0.296369
# TFE Out flow PV                              -0.143039
# TFE Production solids PV                      0.266060
# TFE Production solids density                 0.053475
# TFE Steam pressure PV                         0.206295
# TFE Steam temperature                         0.030357
# TFE Tank level                                0.084839
# TFE Temperature                              -0.025384
# TFE Vacuum pressure PV                       -0.267474
# Class                                        -0.075945
#
#                                FFTE Production solids SP  \
# FFTE Feed tank level SP                        -0.091925
# FFTE Production solids SP                       1.000000
# FFTE Steam pressure SP                          0.036744
# TFE Out flow SP                                 0.552262
# TFE Production solids SP                        0.316578
# TFE Vacuum pressure SP                          0.197538
# TFE Steam pressure SP                          -0.095635
# FFTE Feed flow SP                               0.266580
# FFTE Out steam temp SP                          0.082666
# Extract tank Level                             -0.025623
# Extract tank Out flow PV                       -0.004238
# FFTE Discharge density                          0.033174
# FFTE Discharge solids                          -0.015012
# FFTE Feed flow rate PV                          0.083527
# FFTE Feed tank level PV                        -0.068099
# FFTE Heat temperature 1                         0.205259
# FFTE Heat temperature 2                         0.027769
# FFTE Heat temperature 3                        -0.041037
# FFTE Out steam temp PV                         -0.018815
# FFTE Production solids PV                      -0.011220
# FFTE Pump 1                                    -0.007288
# FFTE Pump 1 - 2                                 0.013091
# FFTE Pump 2                                    -0.020872
# FFTE Steam pressure PV                          0.146112
# FFTE Temperature 1 - 1                         -0.084580
# FFTE Temperature 1 - 2                         -0.013692
# FFTE Temperature 2 - 1                         -0.024564
# FFTE Temperature 2 - 2                          0.092968
# FFTE Temperature 3 - 1                          0.354503
# FFTE Temperature 3 - 2                         -0.081819
# FFTE Unk Temperature                            0.047941
# TFE Feed pump                                  -0.043770
# TFE Input flow PV                               0.000796
# TFE Level                                      -0.037469
# TFE Motor current                              -0.085226
# TFE Motor speed                                -0.054974
# TFE Out flow PV                                -0.006706
# TFE Production solids PV                        0.076988
# TFE Production solids density                   0.047018
# TFE Steam pressure PV                          -0.018415
# TFE Steam temperature                           0.062681
# TFE Tank level                                 -0.041445
# TFE Temperature                                 0.067010
# TFE Vacuum pressure PV                          0.075994
# Class                                           0.134056
#
#                                FFTE Steam pressure SP  TFE Out flow SP  \
# FFTE Feed tank level SP                     -0.244767        -0.047703
# FFTE Production solids SP                    0.036744         0.552262
# FFTE Steam pressure SP                       1.000000        -0.065921
# TFE Out flow SP                             -0.065921         1.000000
# TFE Production solids SP                    -0.045788         0.278106
# TFE Vacuum pressure SP                      -0.107372         0.272331
# TFE Steam pressure SP                       -0.295254        -0.066114
# FFTE Feed flow SP                            0.277625         0.309181
# FFTE Out steam temp SP                       0.074718         0.014353
# Extract tank Level                          -0.059440         0.045048
# Extract tank Out flow PV                     0.080815        -0.027891
# FFTE Discharge density                      -0.108995         0.016544
# FFTE Discharge solids                       -0.212456         0.015352
# FFTE Feed flow rate PV                       0.158045         0.111789
# FFTE Feed tank level PV                     -0.126924        -0.040387
# FFTE Heat temperature 1                      0.096566        -0.162504
# FFTE Heat temperature 2                     -0.106241        -0.023026
# FFTE Heat temperature 3                     -0.157002        -0.041801
# FFTE Out steam temp PV                       0.009664        -0.033648
# FFTE Production solids PV                   -0.210472         0.016461
# FFTE Pump 1                                 -0.121094        -0.005527
# FFTE Pump 1 - 2                             -0.062368         0.024592
# FFTE Pump 2                                 -0.151429        -0.026186
# FFTE Steam pressure PV                       0.183600         0.015556
# FFTE Temperature 1 - 1                      -0.156684        -0.160527
# FFTE Temperature 1 - 2                      -0.176339        -0.082169
# FFTE Temperature 2 - 1                      -0.093582        -0.177671
# FFTE Temperature 2 - 2                      -0.013083         0.007814
# FFTE Temperature 3 - 1                       0.207595        -0.063213
# FFTE Temperature 3 - 2                      -0.156810        -0.158091
# FFTE Unk Temperature                        -0.041248         0.036161
# TFE Feed pump                                0.004080        -0.001326
# TFE Input flow PV                            0.108767         0.017177
# TFE Level                                    0.072050        -0.018634
# TFE Motor current                           -0.111545        -0.056052
# TFE Motor speed                             -0.161491        -0.073306
# TFE Out flow PV                              0.047770         0.040422
# TFE Production solids PV                    -0.169390         0.009211
# TFE Production solids density               -0.053846        -0.011188
# TFE Steam pressure PV                       -0.127254        -0.021794
# TFE Steam temperature                       -0.040058         0.057906
# TFE Tank level                              -0.104079        -0.061985
# TFE Temperature                             -0.005122         0.049072
# TFE Vacuum pressure PV                       0.144156         0.074671
# Class                                        0.099521         0.176178
#
#                                TFE Production solids SP  \
# FFTE Feed tank level SP                        0.312707
# FFTE Production solids SP                      0.316578
# FFTE Steam pressure SP                        -0.045788
# TFE Out flow SP                                0.278106
# TFE Production solids SP                       1.000000
# TFE Vacuum pressure SP                        -0.164310
# TFE Steam pressure SP                          0.385506
# FFTE Feed flow SP                             -0.301060
# FFTE Out steam temp SP                         0.024331
# Extract tank Level                             0.015245
# Extract tank Out flow PV                      -0.082930
# FFTE Discharge density                        -0.013584
# FFTE Discharge solids                          0.032500
# FFTE Feed flow rate PV                        -0.031039
# FFTE Feed tank level PV                        0.004427
# FFTE Heat temperature 1                        0.108595
# FFTE Heat temperature 2                        0.066548
# FFTE Heat temperature 3                        0.048152
# FFTE Out steam temp PV                        -0.007194
# FFTE Production solids PV                      0.037792
# FFTE Pump 1                                    0.019893
# FFTE Pump 1 - 2                                0.002479
# FFTE Pump 2                                    0.022707
# FFTE Steam pressure PV                         0.038845
# FFTE Temperature 1 - 1                         0.032100
# FFTE Temperature 1 - 2                         0.040473
# FFTE Temperature 2 - 1                         0.049771
# FFTE Temperature 2 - 2                         0.085308
# FFTE Temperature 3 - 1                         0.154726
# FFTE Temperature 3 - 2                         0.033177
# FFTE Unk Temperature                           0.033049
# TFE Feed pump                                 -0.043048
# TFE Input flow PV                             -0.033340
# TFE Level                                     -0.009402
# TFE Motor current                             -0.036810
# TFE Motor speed                                0.016686
# TFE Out flow PV                               -0.024611
# TFE Production solids PV                       0.068241
# TFE Production solids density                  0.010475
# TFE Steam pressure PV                          0.044058
# TFE Steam temperature                          0.032216
# TFE Tank level                                -0.042448
# TFE Temperature                                0.013151
# TFE Vacuum pressure PV                        -0.012161
# Class                                          0.020826
#
#                                TFE Vacuum pressure SP  TFE Steam pressure SP  \
# FFTE Feed tank level SP                     -0.272909               0.564166
# FFTE Production solids SP                    0.197538              -0.095635
# FFTE Steam pressure SP                      -0.107372              -0.295254
# TFE Out flow SP                              0.272331              -0.066114
# TFE Production solids SP                    -0.164310               0.385506
# TFE Vacuum pressure SP                       1.000000              -0.241671
# TFE Steam pressure SP                       -0.241671               1.000000
# FFTE Feed flow SP                            0.303772              -0.838869
# FFTE Out steam temp SP                       0.013944              -0.042486
# Extract tank Level                          -0.004955               0.023240
# Extract tank Out flow PV                     0.031645              -0.170127
# FFTE Discharge density                       0.067544               0.018122
# FFTE Discharge solids                       -0.074323               0.350906
# FFTE Feed flow rate PV                       0.114823              -0.283863
# FFTE Feed tank level PV                     -0.098589               0.231578
# FFTE Heat temperature 1                     -0.128430               0.077935
# FFTE Heat temperature 2                     -0.080844               0.235542
# FFTE Heat temperature 3                     -0.108477               0.248847
# FFTE Out steam temp PV                      -0.028359               0.053927
# FFTE Production solids PV                   -0.075594               0.346600
# FFTE Pump 1                                 -0.021429               0.129722
# FFTE Pump 1 - 2                              0.023527               0.010823
# FFTE Pump 2                                 -0.053105               0.212239
# FFTE Steam pressure PV                      -0.033402              -0.071830
# FFTE Temperature 1 - 1                      -0.117492               0.222154
# FFTE Temperature 1 - 2                      -0.053896               0.192757
# FFTE Temperature 2 - 1                      -0.126571               0.214099
# FFTE Temperature 2 - 2                      -0.041164               0.172679
# FFTE Temperature 3 - 1                      -0.069146              -0.044826
# FFTE Temperature 3 - 2                      -0.115473               0.220491
# FFTE Unk Temperature                         0.026955               0.124243
# TFE Feed pump                                0.021089               0.064826
# TFE Input flow PV                            0.049193              -0.142824
# TFE Level                                    0.010709              -0.095226
# TFE Motor current                           -0.008030               0.136641
# TFE Motor speed                             -0.113871               0.332227
# TFE Out flow PV                              0.071447              -0.166993
# TFE Production solids PV                    -0.088325               0.328011
# TFE Production solids density               -0.015079               0.123794
# TFE Steam pressure PV                       -0.110576               0.256870
# TFE Steam temperature                        0.043231               0.083389
# TFE Tank level                               0.001082               0.064548
# TFE Temperature                              0.067584               0.038719
# TFE Vacuum pressure PV                       0.143266              -0.277771
# Class                                        0.113435              -0.022117
#
#                                FFTE Feed flow SP  FFTE Out steam temp SP  \
# FFTE Feed tank level SP                -0.523272                0.032591
# FFTE Production solids SP               0.266580                0.082666
# FFTE Steam pressure SP                  0.277625                0.074718
# TFE Out flow SP                         0.309181                0.014353
# TFE Production solids SP               -0.301060                0.024331
# TFE Vacuum pressure SP                  0.303772                0.013944
# TFE Steam pressure SP                  -0.838869               -0.042486
# FFTE Feed flow SP                       1.000000                0.047579
# FFTE Out steam temp SP                  0.047579                1.000000
# Extract tank Level                     -0.013352               -0.017095
# Extract tank Out flow PV                0.138020               -0.014482
# FFTE Discharge density                 -0.020794               -0.042383
# FFTE Discharge solids                  -0.305289               -0.005777
# FFTE Feed flow rate PV                  0.289349                0.057480
# FFTE Feed tank level PV                -0.216278                0.006340
# FFTE Heat temperature 1                -0.132471                0.165268
# FFTE Heat temperature 2                -0.228609                0.007404
# FFTE Heat temperature 3                -0.249090               -0.014701
# FFTE Out steam temp PV                 -0.065602               -0.004044
# FFTE Production solids PV              -0.302726               -0.000137
# FFTE Pump 1                            -0.129566               -0.022446
# FFTE Pump 1 - 2                        -0.016496               -0.009346
# FFTE Pump 2                            -0.205302               -0.028987
# FFTE Steam pressure PV                  0.061634                0.036375
# FFTE Temperature 1 - 1                 -0.269107               -0.048739
# FFTE Temperature 1 - 2                 -0.209368                0.004471
# FFTE Temperature 2 - 1                 -0.265294               -0.005646
# FFTE Temperature 2 - 2                 -0.164705               -0.026672
# FFTE Temperature 3 - 1                  0.033059                0.282652
# FFTE Temperature 3 - 2                 -0.266763               -0.049083
# FFTE Unk Temperature                   -0.089943               -0.026929
# TFE Feed pump                          -0.069887                0.019547
# TFE Input flow PV                       0.124418                0.041634
# TFE Level                               0.064402                0.060090
# TFE Motor current                      -0.148714               -0.046439
# TFE Motor speed                        -0.308074               -0.026919
# TFE Out flow PV                         0.168568                0.037660
# TFE Production solids PV               -0.292532               -0.008530
# TFE Production solids density          -0.106042               -0.058527
# TFE Steam pressure PV                  -0.235656               -0.047594
# TFE Steam temperature                  -0.049460               -0.023125
# TFE Tank level                         -0.074414               -0.042198
# TFE Temperature                        -0.002708               -0.027986
# TFE Vacuum pressure PV                  0.274173                0.027829
# Class                                   0.112202               -0.053125
#
#                                Extract tank Level  ...  TFE Motor speed  \
# FFTE Feed tank level SP                  0.072949  ...         0.296369
# FFTE Production solids SP               -0.025623  ...        -0.054974
# FFTE Steam pressure SP                  -0.059440  ...        -0.161491
# TFE Out flow SP                          0.045048  ...        -0.073306
# TFE Production solids SP                 0.015245  ...         0.016686
# TFE Vacuum pressure SP                  -0.004955  ...        -0.113871
# TFE Steam pressure SP                    0.023240  ...         0.332227
# FFTE Feed flow SP                       -0.013352  ...        -0.308074
# FFTE Out steam temp SP                  -0.017095  ...        -0.026919
# Extract tank Level                       1.000000  ...         0.195686
# Extract tank Out flow PV                -0.032881  ...        -0.248570
# FFTE Discharge density                  -0.036923  ...         0.051226
# FFTE Discharge solids                    0.240286  ...         0.704768
# FFTE Feed flow rate PV                  -0.138721  ...        -0.781425
# FFTE Feed tank level PV                  0.488897  ...         0.578540
# FFTE Heat temperature 1                  0.111886  ...         0.347821
# FFTE Heat temperature 2                  0.289545  ...         0.598577
# FFTE Heat temperature 3                  0.451487  ...         0.661721
# FFTE Out steam temp PV                   0.039859  ...         0.052877
# FFTE Production solids PV                0.255424  ...         0.704514
# FFTE Pump 1                              0.151825  ...         0.560590
# FFTE Pump 1 - 2                          0.077351  ...         0.245536
# FFTE Pump 2                              0.181932  ...         0.731784
# FFTE Steam pressure PV                  -0.062393  ...        -0.154387
# FFTE Temperature 1 - 1                   0.137341  ...         0.495327
# FFTE Temperature 1 - 2                   0.119049  ...         0.446111
# FFTE Temperature 2 - 1                   0.103527  ...         0.479361
# FFTE Temperature 2 - 2                   0.050065  ...         0.311612
# FFTE Temperature 3 - 1                  -0.069112  ...         0.002756
# FFTE Temperature 3 - 2                   0.143369  ...         0.495497
# FFTE Unk Temperature                     0.043968  ...         0.406774
# TFE Feed pump                           -0.070635  ...        -0.180998
# TFE Input flow PV                       -0.166857  ...        -0.593875
# TFE Level                               -0.056493  ...        -0.492580
# TFE Motor current                        0.118651  ...         0.324262
# TFE Motor speed                          0.195686  ...         1.000000
# TFE Out flow PV                         -0.122099  ...        -0.558385
# TFE Production solids PV                 0.124819  ...         0.656181
# TFE Production solids density           -0.087600  ...         0.081949
# TFE Steam pressure PV                    0.119818  ...         0.749279
# TFE Steam temperature                    0.041924  ...         0.245849
# TFE Tank level                           0.113860  ...         0.134200
# TFE Temperature                          0.003142  ...         0.074123
# TFE Vacuum pressure PV                  -0.152732  ...        -0.727206
# Class                                   -0.058090  ...        -0.045213
#
#                                TFE Out flow PV  TFE Production solids PV  \
# FFTE Feed tank level SP              -0.143039                  0.266060
# FFTE Production solids SP            -0.006706                  0.076988
# FFTE Steam pressure SP                0.047770                 -0.169390
# TFE Out flow SP                       0.040422                  0.009211
# TFE Production solids SP             -0.024611                  0.068241
# TFE Vacuum pressure SP                0.071447                 -0.088325
# TFE Steam pressure SP                -0.166993                  0.328011
# FFTE Feed flow SP                     0.168568                 -0.292532
# FFTE Out steam temp SP                0.037660                 -0.008530
# Extract tank Level                   -0.122099                  0.124819
# Extract tank Out flow PV              0.115467                 -0.212857
# FFTE Discharge density                0.020280                  0.084597
# FFTE Discharge solids                -0.383243                  0.771624
# FFTE Feed flow rate PV                0.608896                 -0.538755
# FFTE Feed tank level PV              -0.425980                  0.451842
# FFTE Heat temperature 1              -0.370493                  0.263961
# FFTE Heat temperature 2              -0.409573                  0.553650
# FFTE Heat temperature 3              -0.461814                  0.559538
# FFTE Out steam temp PV               -0.037560                  0.033889
# FFTE Production solids PV            -0.397307                  0.760386
# FFTE Pump 1                          -0.319433                  0.441556
# FFTE Pump 1 - 2                      -0.055086                  0.184082
# FFTE Pump 2                          -0.442018                  0.577269
# FFTE Steam pressure PV               -0.113723                 -0.145750
# FFTE Temperature 1 - 1               -0.471604                  0.343299
# FFTE Temperature 1 - 2               -0.430791                  0.337156
# FFTE Temperature 2 - 1               -0.452771                  0.315539
# FFTE Temperature 2 - 2               -0.268990                  0.337073
# FFTE Temperature 3 - 1               -0.068627                  0.071100
# FFTE Temperature 3 - 2               -0.472408                  0.342347
# FFTE Unk Temperature                 -0.122718                  0.274689
# TFE Feed pump                         0.278737                 -0.084172
# TFE Input flow PV                     0.478511                 -0.480356
# TFE Level                             0.420619                 -0.387739
# TFE Motor current                    -0.207893                  0.284537
# TFE Motor speed                      -0.558385                  0.656181
# TFE Out flow PV                       1.000000                 -0.382444
# TFE Production solids PV             -0.382444                  1.000000
# TFE Production solids density        -0.000315                  0.091915
# TFE Steam pressure PV                -0.462362                  0.587608
# TFE Steam temperature                -0.031492                  0.233943
# TFE Tank level                        0.097273                  0.274302
# TFE Temperature                       0.083924                  0.125380
# TFE Vacuum pressure PV                0.549852                 -0.553446
# Class                                 0.039491                  0.013828
#
#                                TFE Production solids density  \
# FFTE Feed tank level SP                             0.053475
# FFTE Production solids SP                           0.047018
# FFTE Steam pressure SP                             -0.053846
# TFE Out flow SP                                    -0.011188
# TFE Production solids SP                            0.010475
# TFE Vacuum pressure SP                             -0.015079
# TFE Steam pressure SP                               0.123794
# FFTE Feed flow SP                                  -0.106042
# FFTE Out steam temp SP                             -0.058527
# Extract tank Level                                 -0.087600
# Extract tank Out flow PV                           -0.167560
# FFTE Discharge density                              0.216206
# FFTE Discharge solids                               0.145196
# FFTE Feed flow rate PV                             -0.033855
# FFTE Feed tank level PV                             0.011992
# FFTE Heat temperature 1                            -0.070894
# FFTE Heat temperature 2                             0.085754
# FFTE Heat temperature 3                            -0.033810
# FFTE Out steam temp PV                             -0.020990
# FFTE Production solids PV                           0.136557
# FFTE Pump 1                                         0.019358
# FFTE Pump 1 - 2                                    -0.013057
# FFTE Pump 2                                         0.045084
# FFTE Steam pressure PV                             -0.027500
# FFTE Temperature 1 - 1                             -0.015976
# FFTE Temperature 1 - 2                             -0.057824
# FFTE Temperature 2 - 1                              0.031152
# FFTE Temperature 2 - 2                              0.188212
# FFTE Temperature 3 - 1                             -0.076867
# FFTE Temperature 3 - 2                             -0.019048
# FFTE Unk Temperature                                0.111404
# TFE Feed pump                                       0.088254
# TFE Input flow PV                                  -0.011991
# TFE Level                                          -0.006800
# TFE Motor current                                   0.045681
# TFE Motor speed                                     0.081949
# TFE Out flow PV                                    -0.000315
# TFE Production solids PV                            0.091915
# TFE Production solids density                       1.000000
# TFE Steam pressure PV                               0.053983
# TFE Steam temperature                               0.093294
# TFE Tank level                                      0.056624
# TFE Temperature                                     0.120868
# TFE Vacuum pressure PV                             -0.014124
# Class                                               0.002557
#
#                                TFE Steam pressure PV  TFE Steam temperature  \
# FFTE Feed tank level SP                     0.206295               0.030357
# FFTE Production solids SP                  -0.018415               0.062681
# FFTE Steam pressure SP                     -0.127254              -0.040058
# TFE Out flow SP                            -0.021794               0.057906
# TFE Production solids SP                    0.044058               0.032216
# TFE Vacuum pressure SP                     -0.110576               0.043231
# TFE Steam pressure SP                       0.256870               0.083389
# FFTE Feed flow SP                          -0.235656              -0.049460
# FFTE Out steam temp SP                     -0.047594              -0.023125
# Extract tank Level                          0.119818               0.041924
# Extract tank Out flow PV                   -0.232980              -0.160858
# FFTE Discharge density                      0.020043               0.038554
# FFTE Discharge solids                       0.567945               0.343223
# FFTE Feed flow rate PV                     -0.625422              -0.135354
# FFTE Feed tank level PV                     0.449364               0.116262
# FFTE Heat temperature 1                     0.244411              -0.063714
# FFTE Heat temperature 2                     0.490534               0.233947
# FFTE Heat temperature 3                     0.541669               0.118071
# FFTE Out steam temp PV                      0.067109               0.004157
# FFTE Production solids PV                   0.564380               0.334120
# FFTE Pump 1                                 0.398296               0.076409
# FFTE Pump 1 - 2                             0.137191              -0.015961
# FFTE Pump 2                                 0.540702               0.129707
# FFTE Steam pressure PV                     -0.121168              -0.225632
# FFTE Temperature 1 - 1                      0.380471              -0.101506
# FFTE Temperature 1 - 2                      0.357162              -0.075967
# FFTE Temperature 2 - 1                      0.361100              -0.091727
# FFTE Temperature 2 - 2                      0.252048               0.183912
# FFTE Temperature 3 - 1                     -0.011320              -0.026076
# FFTE Temperature 3 - 2                      0.381469              -0.100869
# FFTE Unk Temperature                        0.462287               0.798313
# TFE Feed pump                              -0.170705               0.022449
# TFE Input flow PV                          -0.496136              -0.179983
# TFE Level                                  -0.420975              -0.082837
# TFE Motor current                           0.284310               0.020631
# TFE Motor speed                             0.749279               0.245849
# TFE Out flow PV                            -0.462362              -0.031492
# TFE Production solids PV                    0.587608               0.233943
# TFE Production solids density               0.053983               0.093294
# TFE Steam pressure PV                       1.000000               0.337611
# TFE Steam temperature                       0.337611               1.000000
# TFE Tank level                              0.137848               0.136688
# TFE Temperature                             0.118571               0.743082
# TFE Vacuum pressure PV                     -0.607483               0.204645
# Class                                       0.019552               0.138739
#
#                                TFE Tank level  TFE Temperature  \
# FFTE Feed tank level SP              0.084839        -0.025384
# FFTE Production solids SP           -0.041445         0.067010
# FFTE Steam pressure SP              -0.104079        -0.005122
# TFE Out flow SP                     -0.061985         0.049072
# TFE Production solids SP            -0.042448         0.013151
# TFE Vacuum pressure SP               0.001082         0.067584
# TFE Steam pressure SP                0.064548         0.038719
# FFTE Feed flow SP                   -0.074414        -0.002708
# FFTE Out steam temp SP              -0.042198        -0.027986
# Extract tank Level                   0.113860         0.003142
# Extract tank Out flow PV            -0.088832        -0.113143
# FFTE Discharge density               0.062271         0.045727
# FFTE Discharge solids                0.139178         0.287281
# FFTE Feed flow rate PV              -0.103130        -0.004283
# FFTE Feed tank level PV              0.055813         0.029967
# FFTE Heat temperature 1             -0.124589        -0.142077
# FFTE Heat temperature 2             -0.045743         0.154336
# FFTE Heat temperature 3              0.032687         0.002754
# FFTE Out steam temp PV              -0.005332        -0.003682
# FFTE Production solids PV            0.130176         0.279226
# FFTE Pump 1                          0.087081        -0.042712
# FFTE Pump 1 - 2                      0.041254        -0.082803
# FFTE Pump 2                          0.115591        -0.008231
# FFTE Steam pressure PV              -0.287091        -0.240357
# FFTE Temperature 1 - 1              -0.094108        -0.197620
# FFTE Temperature 1 - 2              -0.044006        -0.175472
# FFTE Temperature 2 - 1              -0.109366        -0.179059
# FFTE Temperature 2 - 2              -0.126441         0.179721
# FFTE Temperature 3 - 1              -0.064186        -0.043470
# FFTE Temperature 3 - 2              -0.096614        -0.198231
# FFTE Unk Temperature                 0.112656         0.784346
# TFE Feed pump                       -0.095313         0.085739
# TFE Input flow PV                   -0.168390        -0.102256
# TFE Level                           -0.070823        -0.001318
# TFE Motor current                    0.003279        -0.072296
# TFE Motor speed                      0.134200         0.074123
# TFE Out flow PV                      0.097273         0.083924
# TFE Production solids PV             0.274302         0.125380
# TFE Production solids density        0.056624         0.120868
# TFE Steam pressure PV                0.137848         0.118571
# TFE Steam temperature                0.136688         0.743082
# TFE Tank level                       1.000000         0.146678
# TFE Temperature                      0.146678         1.000000
# TFE Vacuum pressure PV              -0.030415         0.488208
# Class                                0.001363         0.192397
#
#                                TFE Vacuum pressure PV     Class
# FFTE Feed tank level SP                     -0.267474 -0.075945
# FFTE Production solids SP                    0.075994  0.134056
# FFTE Steam pressure SP                       0.144156  0.099521
# TFE Out flow SP                              0.074671  0.176178
# TFE Production solids SP                    -0.012161  0.020826
# TFE Vacuum pressure SP                       0.143266  0.113435
# TFE Steam pressure SP                       -0.277771 -0.022117
# FFTE Feed flow SP                            0.274173  0.112202
# FFTE Out steam temp SP                       0.027829 -0.053125
# Extract tank Level                          -0.152732 -0.058090
# Extract tank Out flow PV                     0.147293  0.017496
# FFTE Discharge density                       0.001375 -0.100412
# FFTE Discharge solids                       -0.478180  0.003823
# FFTE Feed flow rate PV                       0.686487  0.116810
# FFTE Feed tank level PV                     -0.500876 -0.068760
# FFTE Heat temperature 1                     -0.368957 -0.132801
# FFTE Heat temperature 2                     -0.440047  0.015496
# FFTE Heat temperature 3                     -0.579004 -0.084729
# FFTE Out steam temp PV                      -0.038240 -0.034880
# FFTE Production solids PV                   -0.480667 -0.004317
# FFTE Pump 1                                 -0.431026 -0.067724
# FFTE Pump 1 - 2                             -0.169816 -0.049116
# FFTE Pump 2                                 -0.572830 -0.071987
# FFTE Steam pressure PV                       0.004832  0.062876
# FFTE Temperature 1 - 1                      -0.555390 -0.209386
# FFTE Temperature 1 - 2                      -0.496900 -0.177080
# FFTE Temperature 2 - 1                      -0.520979 -0.192415
# FFTE Temperature 2 - 2                      -0.190215  0.080902
# FFTE Temperature 3 - 1                      -0.012140 -0.024660
# FFTE Temperature 3 - 2                      -0.554548 -0.209227
# FFTE Unk Temperature                         0.108427  0.121859
# TFE Feed pump                                0.206653  0.025588
# TFE Input flow PV                            0.456090  0.005378
# TFE Level                                    0.436330  0.031577
# TFE Motor current                           -0.352872  0.081827
# TFE Motor speed                             -0.727206 -0.045213
# TFE Out flow PV                              0.549852  0.039491
# TFE Production solids PV                    -0.553446  0.013828
# TFE Production solids density               -0.014124  0.002557
# TFE Steam pressure PV                       -0.607483  0.019552
# TFE Steam temperature                        0.204645  0.138739
# TFE Tank level                              -0.030415  0.001363
# TFE Temperature                              0.488208  0.192397
# TFE Vacuum pressure PV                       1.000000  0.113242
# Class                                        0.113242  1.000000
#
# [45 rows x 45 columns]

# %%
corr = train_df.select_dtypes(include=[np.number]).corr()

# %%
plt.figure(figsize=(14, 12))
sns.heatmap(corr, annot=False, cmap='coolwarm', center=0)
plt.title("Correlation Matrix")
plt.tight_layout()

# %%
# Average temperature 
train_df['FFTE_avg_temperature'] = (train_df['FFTE Temperature 1 - 1'] + 
                                   train_df['FFTE Temperature 1 - 2'] +
                                   train_df['FFTE Temperature 2 - 1'] +
                                   train_df['FFTE Temperature 3 - 2'] ) / 4

# Ratio between feed flow and steam pressure setpoints  
train_df['flow_pressure_ratio'] = train_df['FFTE Feed flow SP'] / train_df['FFTE Steam pressure SP']

# Deviation between actual and target solids 
train_df['FFTE_Production_solids_deviation'] = train_df['FFTE Production solids PV'] - train_df['FFTE Production solids SP']

# %% [markdown]
# ### 5. Checking the final features count

# %%
num_features = len([col for col in train_df.columns if col != 'Class'])

print(num_features)
# Out:
# 47

# %% [markdown]
# # Step 2: Feature Selection, Model Training and Evaluation

# %% [markdown]
# ### 6. Feature Selection with SelectKBest

# %%
X_train = train_df.drop("Class", axis=1)
y_train = train_df["Class"]
X_test = test_df.drop("Class", axis=1)
y_test = test_df["Class"]

X_train = pd.get_dummies(X_train, drop_first=True)
X_test = pd.get_dummies(X_test, drop_first=True)

missing_cols = set(X_train.columns) - set(X_test.columns)
for col in missing_cols:
    X_test[col] = 0

selector = SelectKBest(f_classif, k='all')
selector.fit(X_train, y_train)

feature_scores = pd.DataFrame({
    'Feature': X_train.columns,
    'Score' : selector.scores_
})

feature_scores = feature_scores.sort_values('Score', ascending = False)

# %%
top_features = feature_scores.head(20)['Feature'].values
X_train_selected = X_train[top_features]
X_test_selected = X_test[top_features]

# %% [markdown]
# ### 7. Multiple Models Traning & 8. Models Evaluating & 9. Model Comparing

# %%
# Model training and evaluation
models = {
    'Decision Tree': DecisionTreeClassifier(random_state=42),
    'Random Forest': RandomForestClassifier(random_state=42, n_estimators=100),
    'Gradient Boosting': GradientBoostingClassifier(random_state=42),
    'SVM': SVC(random_state=42),
    'KNN': KNeighborsClassifier(n_neighbors=5)
}

results = {}
model_performances = {}

for name, model in models.items():
    model.fit(X_train_selected, y_train)

    y_pred = model.predict(X_test_selected)
    
    # Evaluate model
    accuracy = accuracy_score(y_test, y_pred)
    report = classification_report(y_test, y_pred, output_dict=True)
    conf_matrix = confusion_matrix(y_test, y_pred)
    
    # Store results
    results[name] = {
        'model': model,
        'accuracy': accuracy,
        'report': report,
        'confusion_matrix': conf_matrix
    }
    
    # Store performance metrics for comparison
    model_performances[name] = {
        'Accuracy': accuracy,
        'Precision (macro avg)': report['macro avg']['precision'],
        'Recall (macro avg)': report['macro avg']['recall'],
        'F1-score (macro avg)': report['macro avg']['f1-score']
    }
    
    print(f"\nModel: {name}")
    print(f"Accuracy: {accuracy:.4f}")
    print("Classification Report:")
    print(classification_report(y_test, y_pred))
    print("Confusion Matrix:")
    print(conf_matrix)

# Create a comparison table
comparison_df = pd.DataFrame(model_performances).T
print("\nModel Comparison:")
print(comparison_df)
# Out:
# Model: Decision Tree
# Accuracy: 0.8400
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.71      0.79       334
#            1       0.74      0.90      0.81       333
#            2       0.93      0.91      0.92       333
#
#     accuracy                           0.84      1000
#    macro avg       0.85      0.84      0.84      1000
# weighted avg       0.85      0.84      0.84      1000
#
# Confusion Matrix:
# [[237  87  10]
#  [ 19 300  14]
#  [ 13  17 303]]
#
# Model: Random Forest
# Accuracy: 0.9940
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       334
#            1       0.99      1.00      0.99       333
#            2       1.00      0.99      1.00       333
#
#     accuracy                           0.99      1000
#    macro avg       0.99      0.99      0.99      1000
# weighted avg       0.99      0.99      0.99      1000
#
# Confusion Matrix:
# [[331   2   1]
#  [  1 332   0]
#  [  0   2 331]]
#
# Model: Gradient Boosting
# Accuracy: 0.8820
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.90       334
#            1       0.88      0.87      0.88       333
#            2       0.87      0.86      0.87       333
#
#     accuracy                           0.88      1000
#    macro avg       0.88      0.88      0.88      1000
# weighted avg       0.88      0.88      0.88      1000
#
# Confusion Matrix:
# [[304  12  18]
#  [ 18 291  24]
#  [ 17  29 287]]
#
# Model: SVM
# Accuracy: 0.4730
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.43      0.80      0.56       334
#            1       0.76      0.04      0.07       333
#            2       0.54      0.58      0.56       333
#
#     accuracy                           0.47      1000
#    macro avg       0.58      0.47      0.40      1000
# weighted avg       0.58      0.47      0.40      1000
#
# Confusion Matrix:
# [[266   0  68]
#  [220  13 100]
#  [135   4 194]]
#
# Model: KNN
# Accuracy: 0.9030
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92       334
#            1       0.90      0.88      0.89       333
#            2       0.90      0.91      0.90       333
#
#     accuracy                           0.90      1000
#    macro avg       0.90      0.90      0.90      1000
# weighted avg       0.90      0.90      0.90      1000
#
# Confusion Matrix:
# [[309  10  15]
#  [ 22 292  19]
#  [  9  22 302]]
#
# Model Comparison:
#                    Accuracy  Precision (macro avg)  Recall (macro avg)  \
# Decision Tree         0.840               0.850074            0.840131
# Random Forest         0.994               0.994024            0.994003
# Gradient Boosting     0.882               0.881867            0.881972
# SVM                   0.473               0.576320            0.472676
# KNN                   0.903               0.902956            0.902978
#
#                    F1-score (macro avg)
# Decision Tree                  0.839454
# Random Forest                  0.994003
# Gradient Boosting              0.881892
# SVM                            0.396542
# KNN                            0.902881

# %% [markdown]
# ### 10. Best-Performing Model & 11. Save The Best Model

# %%
best_model = comparison_df['F1-score (macro avg)'].idxmax()
print(f"\nBest performing model: {best_model} with F1-score: {comparison_df.loc[best_model, 'F1-score (macro avg)']:.4f}")

# Save the best model
best_model = results[best_model]['model']
with open('best_model.pkl', 'wb') as f:
    pickle.dump(best_model, f)
print(f"Saved best model ({best_model}) to 'best_model.pkl'")
# Out:
# Best performing model: Random Forest with F1-score: 0.9940
# Saved best model (Random Forest) to 'best_model.pkl'

# %%
X_train = X_train_selected
X_test = X_test_selected

# %% [markdown]
# # Step 3: Machine Learning to Artificial Intelligence

# %% [markdown]
# ### 12. Take the unuse 1000 rows & 13. Load the Model

# %%
with open('best_model.pkl','rb') as f:
    loaded_model = pickle.load(f) 
loaded_model
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# ### 14. Formatting the test data with the same features as training

# %%
X_test = test_df.drop('Class', axis=1)
y_test = test_df['Class']

X_test = pd.get_dummies(X_test, drop_first=True)

missing_cols = set(X_train.columns) - set(X_test.columns)
for col in missing_cols:
    X_test[col] = 0

# %% [markdown]
# ### 15. Make predictions using loaded model & 16. Measure performance

# %%
y_pred = loaded_model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

print("\nClassification Report:")
print(report)
print("\nConfusion Matrix:")
print(conf_matrix)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       334
#            1       0.99      1.00      0.99       333
#            2       1.00      0.99      1.00       333
#
#     accuracy                           0.99      1000
#    macro avg       0.99      0.99      0.99      1000
# weighted avg       0.99      0.99      0.99      1000
#
#
# Confusion Matrix:
# [[331   2   1]
#  [  1 332   0]
#  [  0   2 331]]

# %%
plt.figure(figsize=(14, 12))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title(f'Confusion Matrix - {best_model} on Test Data')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
# Out:
# Text(145.72222222222223, 0.5, 'True Label')

# %% [markdown]
# ### 17. Evaluate all the models on the test set

# %%
all_model_test_performance = {}
for name, model_info in results.items():
    model = model_info['model']
    test_pred = model.predict(X_test)
    test_acc = accuracy_score(y_test, test_pred)
    test_class_report = classification_report(y_test, test_pred, output_dict=True)

    all_model_test_performance[name] = {
        'Test Accuracy': test_acc,
        'Test Precision': test_class_report['macro avg']['precision'],
        'Test Recall': test_class_report['macro avg']['recall'],
        'Test F1-score': test_class_report['macro avg']['f1-score']
    }
test_comparison_df = pd.DataFrame(all_model_test_performance).T
print("\nModel Comparison on Test Dataset:")
print(test_comparison_df)
# Out:
# Model Comparison on Test Dataset:
#                    Test Accuracy  Test Precision  Test Recall  Test F1-score
# Decision Tree              0.840        0.850074     0.840131       0.839454
# Random Forest              0.994        0.994024     0.994003       0.994003
# Gradient Boosting          0.882        0.881867     0.881972       0.881892
# SVM                        0.473        0.576320     0.472676       0.396542
# KNN                        0.903        0.902956     0.902978       0.902881

# %%
test_best_model = test_comparison_df['Test F1-score'].idxmax()
print(f"Best model on test data: {test_best_model}")
# Out:
# Best model on test data: Random Forest

# %% [markdown]
# # Step 4: Develop Rules for Machine Learning Model

# %%
sp_features = [col for col in train_df.columns if col.endswith('SP') and col != 'Class']

sp_features
# Out:
# ['FFTE Feed tank level SP',
#  'FFTE Production solids SP',
#  'FFTE Steam pressure SP',
#  'TFE Out flow SP',
#  'TFE Production solids SP',
#  'TFE Vacuum pressure SP',
#  'TFE Steam pressure SP',
#  'FFTE Feed flow SP',
#  'FFTE Out steam temp SP']

# %%
X_sp_df = train_df[sp_features]
y_sp_df = train_df['Class']

X_sp_encoded_df = pd.get_dummies(X_sp_df, drop_first=True)

X_sp_df = X_sp_encoded_df

dt_model = DecisionTreeClassifier(random_state=42, max_depth=5)
dt_model = dt_model.fit(X_sp_df, y_sp_df)

tree_rules = export_text(dt_model, feature_names=list(X_sp_df.columns))
print("\nDecision Tree Rules: ")
print(tree_rules)
# Out:
# Decision Tree Rules:
# |--- FFTE Feed flow SP <= 10198.77
# |   |--- FFTE Feed flow SP <= 9231.11
# |   |   |--- TFE Out flow SP <= 2173.78
# |   |   |   |--- FFTE Feed tank level SP_50.0 <= 0.50
# |   |   |   |   |--- TFE Production solids SP <= 68.69
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- TFE Production solids SP >  68.69
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- FFTE Feed tank level SP_50.0 >  0.50
# |   |   |   |   |--- FFTE Feed flow SP <= 9200.68
# |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- FFTE Feed flow SP >  9200.68
# |   |   |   |   |   |--- class: 1
# |   |   |--- TFE Out flow SP >  2173.78
# |   |   |   |--- FFTE Production solids SP <= 41.31
# |   |   |   |   |--- TFE Out flow SP <= 2507.03
# |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- TFE Out flow SP >  2507.03
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- FFTE Production solids SP >  41.31
# |   |   |   |   |--- TFE Production solids SP <= 68.95
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- TFE Production solids SP >  68.95
# |   |   |   |   |   |--- class: 1
# |   |--- FFTE Feed flow SP >  9231.11
# |   |   |--- FFTE Steam pressure SP <= 128.52
# |   |   |   |--- FFTE Out steam temp SP <= 49.28
# |   |   |   |   |--- FFTE Production solids SP <= 40.50
# |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- FFTE Production solids SP >  40.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- FFTE Out steam temp SP >  49.28
# |   |   |   |   |--- TFE Out flow SP <= 2067.13
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- TFE Out flow SP >  2067.13
# |   |   |   |   |   |--- class: 0
# |   |   |--- FFTE Steam pressure SP >  128.52
# |   |   |   |--- TFE Steam pressure SP <= 84.07
# |   |   |   |   |--- FFTE Production solids SP <= 40.11
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- FFTE Production solids SP >  40.11
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- TFE Steam pressure SP >  84.07
# |   |   |   |   |--- FFTE Feed flow SP <= 9499.99
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- FFTE Feed flow SP >  9499.99
# |   |   |   |   |   |--- class: 2
# |--- FFTE Feed flow SP >  10198.77
# |   |--- TFE Production solids SP <= 84.60
# |   |   |--- FFTE Out steam temp SP <= 50.14
# |   |   |   |--- TFE Production solids SP <= 66.99
# |   |   |   |   |--- FFTE Steam pressure SP <= 117.03
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- FFTE Steam pressure SP >  117.03
# |   |   |   |   |   |--- class: 2
# |   |   |   |--- TFE Production solids SP >  66.99
# |   |   |   |   |--- TFE Production solids SP <= 78.09
# |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- TFE Production solids SP >  78.09
# |   |   |   |   |   |--- class: 1
# |   |   |--- FFTE Out steam temp SP >  50.14
# |   |   |   |--- FFTE Out steam temp SP <= 51.10
# |   |   |   |   |--- FFTE Steam pressure SP <= 127.64
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- FFTE Steam pressure SP >  127.64
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- FFTE Out steam temp SP >  51.10
# |   |   |   |   |--- FFTE Feed flow SP <= 10299.85
# |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- FFTE Feed flow SP >  10299.85
# |   |   |   |   |   |--- class: 2
# |   |--- TFE Production solids SP >  84.60
# |   |   |--- FFTE Feed tank level SP_50.0 <= 0.50
# |   |   |   |--- TFE Vacuum pressure SP <= -40.68
# |   |   |   |   |--- TFE Vacuum pressure SP <= -63.66
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- TFE Vacuum pressure SP >  -63.66
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- TFE Vacuum pressure SP >  -40.68
# |   |   |   |   |--- class: 2
# |   |   |--- FFTE Feed tank level SP_50.0 >  0.50
# |   |   |   |--- TFE Vacuum pressure SP <= -47.44
# |   |   |   |   |--- class: 2
# |   |   |   |--- TFE Vacuum pressure SP >  -47.44
# |   |   |   |   |--- TFE Steam pressure SP <= 115.00
# |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- TFE Steam pressure SP >  115.00
# |   |   |   |   |   |--- class: 1
